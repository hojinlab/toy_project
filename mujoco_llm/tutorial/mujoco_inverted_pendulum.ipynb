# %% [markdown]
# 1. 환경 & 라이브러리

# %%
import os
os.environ['MUJOCO_GL'] = 'egl'   # mujoco import 전에!
 
import mujoco
import numpy as np
import mediapy as media
import matplotlib.pyplot as plt

# %% [markdown]
# 2. XML 정의

# %%
xml = """
<mujoco model="inverted pendulum">
    <compiler inertiafromgeom="true"/>
    <default>
        <joint armature="0" damping="1" limited="true"/>
        <geom friction="1 0.1 0.1" rgba="0.7 0.7 0 1"/>
        <tendon/>
        <motor ctrlrange="-3 3"/>
    </default>
    <option gravity="0 0 -9.81" integrator="Euler" timestep="0.01"/>
    <size nstack="3000"/>
    <worldbody>
        <!-- 레일 (바닥) -->
        <geom name="rail" pos="0 0 0" quat="0.707 0 0.707 0" rgba="0.3 0.3 0.7 1"
              size="0.02 1" type="capsule" contype="0" conaffinity="0"/>
        
        <!-- 움직이는 카트 (Cart) -->
        <body name="cart" pos="0 0 0">
            <!-- 슬라이드 조인트: 직선 운동 -->
            <joint axis="1 0 0" limited="true" name="slider" pos="0 0 0"
                   range="-1.2 1.2" type="slide"/>
            <geom name="cart" pos="0 0 0" quat="0.707 0 0.707 0"
                  size="0.1 0.1" type="capsule"/>
            
            <!-- 카트 위의 막대 (Pole) -->
            <body name="pole" pos="0 0 0">
                <!-- 힌지 조인트: 회전 운동 -->
                <joint axis="0 1 0" name="hinge" pos="0 0 0"
                       type="hinge" limited="false"/>
                <geom fromto="0 0 0 0.001 0 0.6" name="cpole"
                      rgba="0 0.7 0.7 1" size="0.049 0.3" type="capsule"/>
            </body>
        </body>
    </worldbody>
    <!-- 액추에이터: 카트를 미는 모터 -->
    <actuator>
        <motor ctrllimited="true" ctrlrange="-3 3" gear="10"
               joint="slider" name="slide"/>
    </actuator>
</mujoco>
"""

# %% [markdown]
# Env 관련 유틸 함수들

# %%
def create_env():
    """MuJoCo 모델/데이터/렌더러 생성."""
    model = mujoco.MjModel.from_xml_string(xml)
    data = mujoco.MjData(model)
    renderer = mujoco.Renderer(model, height=480, width=640)
    return model, data, renderer


def reset_state(data, q_init=None, qv_init=None):
    """qpos, qvel 초기화. q_init, qv_init은 리스트나 np.array로 전달."""
    mujoco.mj_resetData(data.model, data)
    if q_init is not None:
        data.qpos[:len(q_init)] = q_init
    if qv_init is not None:
        data.qvel[:len(qv_init)] = qv_init
    mujoco.mj_forward(data.model, data)


def get_state(data):
    """
    상태 벡터 [x_cart, theta_pole, x_dot, theta_dot] 반환.
    qpos[0] : slider joint (cart position)
    qpos[1] : hinge joint (pole angle)
    """
    x = float(data.qpos[0])
    theta = float(data.qpos[1])
    x_dot = float(data.qvel[0])
    theta_dot = float(data.qvel[1])
    return np.array([x, theta, x_dot, theta_dot])


def rollout(model, data, renderer,
            duration=10.0, framerate=60,
            ctrl_func=None,
            q_init=None, qv_init=None):
    """
    한 에피소드 시뮬레이션:
      - ctrl_func(state, t)로 제어 입력 생성 (None이면 0 입력)
      - 상태 궤적과 프레임 기록.

    반환:
      times, states, controls, frames
    """
    reset_state(data, q_init=q_init, qv_init=qv_init)

    dt = model.opt.timestep
    times = []
    states = []
    controls = []
    frames = []

    # 메인 루프
    while data.time < duration:
        t = float(data.time)
        state = get_state(data)

        # 제어 입력 계산
        if ctrl_func is None:
            u = 0.0
        else:
            u = float(ctrl_func(state, t))

        # ctrl 적용
        data.ctrl[0] = u

        # 한 스텝 진행
        mujoco.mj_step(model, data)

        # 로깅
        times.append(t)
        states.append(state)
        controls.append(u)

        # 프레임 샘플링 (대략 framerate에 맞추기)
        if len(frames) < data.time * framerate:
            renderer.update_scene(data)
            pixels = renderer.render()
            frames.append(pixels)

    return (
        np.array(times),
        np.vstack(states),   # shape: [T, 4]
        np.array(controls),  # shape: [T]
        np.array(frames)     # shape: [N_frames, H, W, 3]
    )

def plot_states(times, states, controls=None, title="Cart-Pole States"):
    """
    states: shape [T, 4] = [x, theta, x_dot, theta_dot]
    controls: shape [T] or None
    """
    x = states[:, 0]
    theta = states[:, 1]
    x_dot = states[:, 2]
    theta_dot = states[:, 3]

    if controls is None:
        fig, axs = plt.subplots(2, 2, figsize=(12, 8))
        fig.suptitle(title, fontsize=16)

        axs[0, 0].plot(times, x, label="Cart Position [m]")
        axs[0, 0].set_ylabel("Position [m]")
        axs[0, 0].set_title("Cart Position")
        axs[0, 0].grid(True)
        axs[0, 0].legend()

        axs[0, 1].plot(times, x_dot, "r", label="Cart Velocity [m/s]")
        axs[0, 1].set_ylabel("Velocity [m/s]")
        axs[0, 1].set_title("Cart Velocity")
        axs[0, 1].grid(True)
        axs[0, 1].legend()

        axs[1, 0].plot(times, theta, "g", label="Pole Angle [rad]")
        axs[1, 0].set_ylabel("Angle [rad]")
        axs[1, 0].set_title("Pole Angle")
        axs[1, 0].set_xlabel("Time [s]")
        axs[1, 0].grid(True)
        axs[1, 0].legend()

        axs[1, 1].plot(times, theta_dot, "m", label="Pole Angular Velocity [rad/s]")
        axs[1, 1].set_ylabel("Angular Velocity [rad/s]")
        axs[1, 1].set_title("Pole Angular Velocity")
        axs[1, 1].set_xlabel("Time [s]")
        axs[1, 1].grid(True)
        axs[1, 1].legend()

        plt.tight_layout(rect=[0, 0, 1, 0.96])
        plt.show()

    else:
        fig, axs = plt.subplots(3, 1, figsize=(10, 8), sharex=True)
        fig.suptitle(title, fontsize=16)

        axs[0].plot(times, x, label="Cart Position [m]")
        axs[0].plot(times, theta, label="Pole Angle [rad]")
        axs[0].set_ylabel("Pos / Angle")
        axs[0].grid(True)
        axs[0].legend()

        axs[1].plot(times, x_dot, label="Cart Velocity [m/s]")
        axs[1].plot(times, theta_dot, label="Pole Angular Velocity [rad/s]")
        axs[1].set_ylabel("Vel / Ang. Vel")
        axs[1].grid(True)
        axs[1].legend()

        axs[2].plot(times, controls, "r", label="Control Input [N]")
        axs[2].set_xlabel("Time [s]")
        axs[2].set_ylabel("Force [N]")
        axs[2].grid(True)
        axs[2].legend()

        plt.tight_layout(rect=[0, 0, 1, 0.96])
        plt.show()

# %% [markdown]
# 테스트: 제어 없이 시뮬레이션 + mediapy로 영상 보기

# %%
model, data, renderer = create_env()

# 초기 상태: 폴을 살짝(0.1 rad) 기울인 상태에서 시작
q_init = [0.0, 0.1]  # [x, theta]
qv_init = [0.0, 0.0]   # [x_dot, theta_dot]

duration = 10.0
framerate = 60

times, states, controls, frames = rollout(
    model, data, renderer,
    duration=duration,
    framerate=framerate,
    ctrl_func=None,     # 무제어
    q_init=q_init,
    qv_init=qv_init,
)

print("Simulation finished. Plotting states...")
plot_states(times, states, controls=None, title="Free Cart-Pole Dynamics")
# Out:
# Simulation finished. Plotting states...

# %%
print("Rendering video with mediapy...")
media.show_video(frames, fps=framerate)
# Out:
# Rendering video with mediapy...
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# ***강화학습으로 제어하기***

# %% [markdown]
# Gym 스타일 환경 정의

# %%
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO

class CartPoleMuJoCoEnv(gym.Env):
    metadata = {"render_modes": ["rgb_array"], "render_fps": 60}

    def __init__(self, render_mode=None):
        super().__init__()
        # 기존 유틸 재사용
        self.model, self.data, self.renderer = create_env()
        self.dt = self.model.opt.timestep

        # 관측 공간: [x, theta, x_dot, theta_dot]
        high = np.array([np.inf, np.inf, np.inf, np.inf], dtype=np.float32)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        # 행동 공간: 카트에 가하는 힘 (연속, -3 ~ 3)
        self.action_space = spaces.Box(
            low=np.array([-3.0], dtype=np.float32),
            high=np.array([3.0], dtype=np.float32),
            dtype=np.float32,
        )

        self.render_mode = render_mode
        self.max_steps = int(10.0 / self.dt)  # 에피소드 최대 길이 (대략 10초)
        self.step_count = 0

    def _get_obs(self):
        return get_state(self.data).astype(np.float32)

    def _get_info(self):
        return {}

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.step_count = 0

        # 초기화 시 랜덤하게 약간 기울어지게 함 (-0.15 ~ 0.15 rad)
        theta0 = self.np_random.uniform(-0.15, 0.15)
        q_init = [0.0, theta0]
        qv_init = [0.0, 0.0]
        reset_state(self.data, q_init=q_init, qv_init=qv_init)

        obs = self._get_obs()
        info = self._get_info()
        return obs, info

    def step(self, action):
        self.step_count += 1

        # action은 shape (1,) 이라고 가정
        u = float(np.clip(action[0], -3.0, 3.0))
        self.data.ctrl[0] = u

        # 한 스텝 진행
        mujoco.mj_step(self.model, self.data)

        obs = self._get_obs()
        x, theta, x_dot, theta_dot = obs

        # 보상 설계 (Reward Shaping)
        # 폴이 세워져 있고 카트가 가운데에 있을수록 보상 높게
        cost = (
            1.0 * theta**2 +        # 각도 제곱 (기울어질수록 페널티)
            0.1 * x**2 +            # 위치 제곱 (중앙에서 멀어질수록 페널티)
            0.01 * x_dot**2 +       # 속도 제곱 (너무 빨리 움직이면 페널티)
            0.01 * theta_dot**2 +
            0.001 * u**2            # 제어 입력 제곱 (힘을 많이 쓰면 페널티)
        )
        reward = 1.0 - cost  # 최대 1 근처, 상태가 나쁠수록 작아짐

        # 종료 조건
        terminated = bool(
            abs(theta) > np.pi / 2.0 or  # 폴이 90도 이상 기울어지면 실패
            abs(x) > 1.2                 # 레일 밖으로 나가면 종료
        )
        truncated = bool(self.step_count >= self.max_steps)

        info = self._get_info()
        return obs, reward, terminated, truncated, info

    def render(self):
        # PPO 학습 중에는 호출 안 해도 되고,
        # 나중에 평가할 때 rgb_array로 프레임 뽑는 데 씀
        self.renderer.update_scene(self.data)
        img = self.renderer.render()
        return img

    def close(self):
        pass

# %% [markdown]
# PPO 학습

# %%
# Gymnasium env 인스턴스 생성
env = CartPoleMuJoCoEnv()

# MlpPolicy: 관측 → MLP → 연속 행동
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=1024,
    batch_size=64,
    gamma=0.99,
)

# 학습 스텝 수는 상황 봐가면서 늘려도 됨 (예: 100_000 ~ 300_000)
model.learn(total_timesteps=150_000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/jin/miniconda3/envs/mujoco/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.6     |
# |    ep_rew_mean     | 50.6     |
# | time/              |          |
# |    fps             | 1753     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.7        |
# |    ep_rew_mean          | 50.5        |
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.002022028 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0099      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.993       |
# |    value_loss           | 107         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.6         |
# |    ep_rew_mean          | 49.5         |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0030826202 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0901       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.2         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00376     |
# |    std                  | 0.996        |
# |    value_loss           | 84.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 86.1          |
# |    ep_rew_mean          | 46.8          |
# | time/                   |               |
# |    fps                  | 1204          |
# |    iterations           | 4             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00028880662 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.42          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 15            |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00046      |
# |    std                  | 1.01          |
# |    value_loss           | 48.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.8         |
# |    ep_rew_mean          | 46.5         |
# | time/                   |              |
# |    fps                  | 1201         |
# |    iterations           | 5            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0016035605 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.71         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000194    |
# |    std                  | 1.02         |
# |    value_loss           | 34.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.8         |
# |    ep_rew_mean          | 47.4         |
# | time/                   |              |
# |    fps                  | 1203         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0025254237 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.8         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 1.02         |
# |    value_loss           | 38.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88           |
# |    ep_rew_mean          | 48.5         |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0014568826 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000345    |
# |    std                  | 1.02         |
# |    value_loss           | 30           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | 47.6         |
# | time/                   |              |
# |    fps                  | 1209         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0035774834 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.5         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00195     |
# |    std                  | 1.03         |
# |    value_loss           | 39.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 46.7        |
# | time/                   |             |
# |    fps                  | 1212        |
# |    iterations           | 9           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.003629279 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.7         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 1.05        |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.1        |
# |    ep_rew_mean          | 48.5        |
# | time/                   |             |
# |    fps                  | 1210        |
# |    iterations           | 10          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005179891 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.83        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00408    |
# |    std                  | 1.06        |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.8         |
# |    ep_rew_mean          | 49.3         |
# | time/                   |              |
# |    fps                  | 1210         |
# |    iterations           | 11           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0017252925 |
# |    clip_fraction        | 0.00371      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.85         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000226    |
# |    std                  | 1.06         |
# |    value_loss           | 32.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.1         |
# |    ep_rew_mean          | 49.5         |
# | time/                   |              |
# |    fps                  | 1210         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0021976049 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.95         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 1.06         |
# |    value_loss           | 21           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.6         |
# |    ep_rew_mean          | 52           |
# | time/                   |              |
# |    fps                  | 1213         |
# |    iterations           | 13           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0008637188 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 1.05         |
# |    value_loss           | 22.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92           |
# |    ep_rew_mean          | 52.4         |
# | time/                   |              |
# |    fps                  | 1215         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0037687519 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.96         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 1.05         |
# |    value_loss           | 20.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.2         |
# |    ep_rew_mean          | 51.5         |
# | time/                   |              |
# |    fps                  | 1215         |
# |    iterations           | 15           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0014463628 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.79         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00156     |
# |    std                  | 1.06         |
# |    value_loss           | 14.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.7        |
# |    ep_rew_mean          | 52          |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 16          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.002209715 |
# |    clip_fraction        | 0.0214      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.31        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00264    |
# |    std                  | 1.05        |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.9        |
# |    ep_rew_mean          | 53.1        |
# | time/                   |             |
# |    fps                  | 1212        |
# |    iterations           | 17          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.009452503 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.07        |
# |    value_loss           | 18.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.8         |
# |    ep_rew_mean          | 54           |
# | time/                   |              |
# |    fps                  | 1213         |
# |    iterations           | 18           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0013903056 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.11         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000957    |
# |    std                  | 1.07         |
# |    value_loss           | 16           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.5         |
# |    ep_rew_mean          | 53.6         |
# | time/                   |              |
# |    fps                  | 1215         |
# |    iterations           | 19           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0049569695 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.77         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00621     |
# |    std                  | 1.1          |
# |    value_loss           | 10.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.7         |
# |    ep_rew_mean          | 51.7         |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 20           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0019401892 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000367    |
# |    std                  | 1.09         |
# |    value_loss           | 8.55         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 91.9       |
# |    ep_rew_mean          | 51.8       |
# | time/                   |            |
# |    fps                  | 1215       |
# |    iterations           | 21         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.00421456 |
# |    clip_fraction        | 0.0513     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.27       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00646   |
# |    std                  | 1.11       |
# |    value_loss           | 10.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.3        |
# |    ep_rew_mean          | 52.1        |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 22          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005598677 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.45        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00342    |
# |    std                  | 1.13        |
# |    value_loss           | 18.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.5         |
# |    ep_rew_mean          | 52.1         |
# | time/                   |              |
# |    fps                  | 1211         |
# |    iterations           | 23           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0053804372 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.14         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00469     |
# |    std                  | 1.12         |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.8         |
# |    ep_rew_mean          | 53.3         |
# | time/                   |              |
# |    fps                  | 1210         |
# |    iterations           | 24           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0036828634 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.98         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 1.13         |
# |    value_loss           | 10.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.6        |
# |    ep_rew_mean          | 55          |
# | time/                   |             |
# |    fps                  | 1209        |
# |    iterations           | 25          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.008114867 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.18        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00447    |
# |    std                  | 1.15        |
# |    value_loss           | 9.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.7        |
# |    ep_rew_mean          | 56          |
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 26          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.001150263 |
# |    clip_fraction        | 0.00137     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.84        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000574   |
# |    std                  | 1.15        |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 59.1        |
# | time/                   |             |
# |    fps                  | 1211        |
# |    iterations           | 27          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.004615646 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.88        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00493    |
# |    std                  | 1.14        |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 102           |
# |    ep_rew_mean          | 61            |
# | time/                   |               |
# |    fps                  | 1210          |
# |    iterations           | 28            |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00051552494 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | 0.971         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.5           |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000841     |
# |    std                  | 1.13          |
# |    value_loss           | 14.3          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 63.4        |
# | time/                   |             |
# |    fps                  | 1208        |
# |    iterations           | 29          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.004392487 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.75        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00233    |
# |    std                  | 1.13        |
# |    value_loss           | 9.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 107          |
# |    ep_rew_mean          | 65.5         |
# | time/                   |              |
# |    fps                  | 1208         |
# |    iterations           | 30           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0027543623 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.83         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 1.13         |
# |    value_loss           | 9.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | 68.2         |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 31           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0055233873 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.95         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00447     |
# |    std                  | 1.12         |
# |    value_loss           | 11.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 68.8        |
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 32          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005337861 |
# |    clip_fraction        | 0.0468      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00332    |
# |    std                  | 1.11        |
# |    value_loss           | 7.96        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 115        |
# |    ep_rew_mean          | 73         |
# | time/                   |            |
# |    fps                  | 1205       |
# |    iterations           | 33         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.00804067 |
# |    clip_fraction        | 0.0595     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.77       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00405   |
# |    std                  | 1.11       |
# |    value_loss           | 9.72       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 118          |
# |    ep_rew_mean          | 76           |
# | time/                   |              |
# |    fps                  | 1203         |
# |    iterations           | 34           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0055937786 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.75         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00508     |
# |    std                  | 1.1          |
# |    value_loss           | 10.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | 80.3         |
# | time/                   |              |
# |    fps                  | 1203         |
# |    iterations           | 35           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0071933675 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.64         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00811     |
# |    std                  | 1.1          |
# |    value_loss           | 8.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 127          |
# |    ep_rew_mean          | 83.9         |
# | time/                   |              |
# |    fps                  | 1204         |
# |    iterations           | 36           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0074954056 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00766     |
# |    std                  | 1.08         |
# |    value_loss           | 5.97         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | 85.5         |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 37           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0069433274 |
# |    clip_fraction        | 0.0621       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.29         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00549     |
# |    std                  | 1.07         |
# |    value_loss           | 6.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 87.6         |
# | time/                   |              |
# |    fps                  | 1206         |
# |    iterations           | 38           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0070255646 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00602     |
# |    std                  | 1.04         |
# |    value_loss           | 5.82         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 90.2        |
# | time/                   |             |
# |    fps                  | 1207        |
# |    iterations           | 39          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.005237805 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.4         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00426    |
# |    std                  | 1.04        |
# |    value_loss           | 8.41        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 133        |
# |    ep_rew_mean          | 89.8       |
# | time/                   |            |
# |    fps                  | 1205       |
# |    iterations           | 40         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00856857 |
# |    clip_fraction        | 0.0623     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.988      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.73       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00763   |
# |    std                  | 1.04       |
# |    value_loss           | 5.99       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 93.6        |
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 41          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.007718779 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.11        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00769    |
# |    std                  | 1.04        |
# |    value_loss           | 6.39        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | 99.6         |
# | time/                   |              |
# |    fps                  | 1203         |
# |    iterations           | 42           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0008752934 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.93         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 1.04         |
# |    value_loss           | 43.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 1204         |
# |    iterations           | 43           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0029595818 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.82         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00568     |
# |    std                  | 1.04         |
# |    value_loss           | 14.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 44           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0047518406 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.66         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00487     |
# |    std                  | 1.04         |
# |    value_loss           | 16.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 45           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0007586253 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.1         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000123    |
# |    std                  | 1.03         |
# |    value_loss           | 54.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 1206         |
# |    iterations           | 46           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0065931994 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.3         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00548     |
# |    std                  | 1.03         |
# |    value_loss           | 23.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 125          |
# | time/                   |              |
# |    fps                  | 1207         |
# |    iterations           | 47           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0018260315 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.1         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000617    |
# |    std                  | 1.03         |
# |    value_loss           | 35.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 1207        |
# |    iterations           | 48          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.002587433 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000603   |
# |    std                  | 1.03        |
# |    value_loss           | 43.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 135          |
# | time/                   |              |
# |    fps                  | 1208         |
# |    iterations           | 49           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0026710974 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 1.03         |
# |    value_loss           | 30.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | 137          |
# | time/                   |              |
# |    fps                  | 1208         |
# |    iterations           | 50           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0036871869 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00489     |
# |    std                  | 1.05         |
# |    value_loss           | 3.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 184          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 1209         |
# |    iterations           | 51           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0023552186 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00338     |
# |    std                  | 1.05         |
# |    value_loss           | 7.28         |
# ------------------------------------------
# -----------------------------------------
# ...
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 818         |
# |    ep_rew_mean          | 797         |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 131         |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 134144      |
# | train/                  |             |
# |    approx_kl            | 0.003724108 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0225      |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.00119    |
# |    std                  | 0.711       |
# |    value_loss           | 0.00025     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 827          |
# |    ep_rew_mean          | 806          |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 132          |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0046486035 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0122      |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00299     |
# |    std                  | 0.703        |
# |    value_loss           | 0.0018       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 835         |
# |    ep_rew_mean          | 814         |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 133         |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 136192      |
# | train/                  |             |
# |    approx_kl            | 0.008079474 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00572    |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00556    |
# |    std                  | 0.693       |
# |    value_loss           | 0.00034     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | 815         |
# | time/                   |             |
# |    fps                  | 1216        |
# |    iterations           | 134         |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 137216      |
# | train/                  |             |
# |    approx_kl            | 0.005402186 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00489     |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00704    |
# |    std                  | 0.694       |
# |    value_loss           | 0.000243    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 844          |
# |    ep_rew_mean          | 824          |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 135          |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 138240       |
# | train/                  |              |
# |    approx_kl            | 0.0048889136 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0147       |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00287     |
# |    std                  | 0.68         |
# |    value_loss           | 0.000383     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 844          |
# |    ep_rew_mean          | 824          |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 136          |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0031177904 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00174     |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 0.663        |
# |    value_loss           | 0.000213     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 847         |
# |    ep_rew_mean          | 827         |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 137         |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 140288      |
# | train/                  |             |
# |    approx_kl            | 0.006396043 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00399    |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.656       |
# |    value_loss           | 0.000275    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 853          |
# |    ep_rew_mean          | 833          |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 138          |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 141312       |
# | train/                  |              |
# |    approx_kl            | 0.0058022616 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00296     |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00335     |
# |    std                  | 0.662        |
# |    value_loss           | 0.000239     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 862          |
# |    ep_rew_mean          | 842          |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 139          |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 142336       |
# | train/                  |              |
# |    approx_kl            | 0.0072116246 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00315     |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00217     |
# |    std                  | 0.653        |
# |    value_loss           | 0.000664     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | 851         |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 140         |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.005129327 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00823     |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00274    |
# |    std                  | 0.645       |
# |    value_loss           | 0.000164    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 859          |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 141          |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 144384       |
# | train/                  |              |
# |    approx_kl            | 0.0046821916 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00845      |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00226     |
# |    std                  | 0.642        |
# |    value_loss           | 0.000145     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 887         |
# |    ep_rew_mean          | 867         |
# | time/                   |             |
# |    fps                  | 1218        |
# |    iterations           | 142         |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 145408      |
# | train/                  |             |
# |    approx_kl            | 0.004447784 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0105     |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 0.65        |
# |    value_loss           | 0.000189    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 896          |
# |    ep_rew_mean          | 876          |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 143          |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 146432       |
# | train/                  |              |
# |    approx_kl            | 0.0036717306 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00864     |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.642        |
# |    value_loss           | 0.000107     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | 880          |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 144          |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0053459727 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.967       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.016       |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | 0.000616     |
# |    std                  | 0.632        |
# |    value_loss           | 0.00106      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 888          |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 145          |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 148480       |
# | train/                  |              |
# |    approx_kl            | 0.0038901325 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.947       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0258      |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.00763     |
# |    std                  | 0.617        |
# |    value_loss           | 0.000232     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 911          |
# |    ep_rew_mean          | 891          |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 146          |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0068472605 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00581      |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00303     |
# |    std                  | 0.598        |
# |    value_loss           | 8.32e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 914          |
# |    ep_rew_mean          | 895          |
# | time/                   |              |
# |    fps                  | 1216         |
# |    iterations           | 147          |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 150528       |
# | train/                  |              |
# |    approx_kl            | 0.0053207027 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00186      |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00422     |
# |    std                  | 0.586        |
# |    value_loss           | 4.22e-05     |
# ------------------------------------------

# %%
# 학습된 모델 저장
model.save("ppo_cartpole_mujoco")

# %% [markdown]
# 학습된 정책 성능 보기 (mediapy + 상태 플롯)

# %%
eval_env = CartPoleMuJoCoEnv()
obs, info = eval_env.reset()

duration = 10.0
framerate = 60
max_steps = int(duration / eval_env.dt)

frames = []
times = []
states = []
controls = []

print("Running Evaluation Episode...")
for step in range(max_steps):
    # 학습된 정책(AI)에게 현재 상태를 보여주고 행동(Action)을 결정하게 함
    # deterministic=True: 확률적 탐색을 끄고 가장 좋은 행동만 선택
    action, _ = model.predict(obs, deterministic=True)

    # 환경에 행동 적용
    obs, reward, terminated, truncated, info = eval_env.step(action)

    # 기록
    state = get_state(eval_env.data)
    states.append(state)
    controls.append(float(action[0]))
    times.append(eval_env.data.time)

    # 영상 프레임 저장
    frame = eval_env.render()
    frames.append(frame)

    if terminated or truncated:
        print(f"Episode ended at step {step}")
        break

states = np.vstack(states)
controls = np.array(controls)
times = np.array(times)

print("Evaluation finished. Plotting states...")
plot_states(times, states, controls=controls, title="PPO-Controlled Cart-Pole")
# Out:
# Running Evaluation Episode...
# Episode ended at step 999
# Evaluation finished. Plotting states...

# %% [markdown]
# 결과 재생

# %%
print("Rendering PPO policy video with mediapy...")
media.show_video(frames, fps=framerate)
# Out:
# Rendering PPO policy video with mediapy...
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
